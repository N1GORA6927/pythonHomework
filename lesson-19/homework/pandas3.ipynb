# %%
import pandas as pd
df=pd.read_csv('employee.csv')
df
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
deps=['Houston Police Department-HPD','Houston Fire Department (HFD)']
filt=(df['DEPARTMENT'].isin(deps))&(df['GENDER']=='Female')&(df['BASE_SALARY'].between(80000,120000))
df=df[filt]
df
# Out:
#       UNIQUE_ID      POSITION_TITLE                     DEPARTMENT  \
# 61           61  IT PROJECT MANAGER  Houston Fire Department (HFD)
# 136         136     POLICE SERGEANT  Houston Police Department-HPD
# 367         367   POLICE LIEUTENANT  Houston Police Department-HPD
# 474         474   POLICE LIEUTENANT  Houston Police Department-HPD
# 513         513     POLICE SERGEANT  Houston Police Department-HPD
# 564         564     POLICE SERGEANT  Houston Police Department-HPD
# 595         595  STAFF PSYCHOLOGIST  Houston Police Department-HPD
# 937         937     POLICE SERGEANT  Houston Police Department-HPD
# 954         954   POLICE LIEUTENANT  Houston Police Department-HPD
# 1118       1118      POLICE CAPTAIN  Houston Police Department-HPD
# 1519       1519   POLICE LIEUTENANT  Houston Police Department-HPD
# 1565       1565     POLICE SERGEANT  Houston Police Department-HPD
# 1622       1622   POLICE LIEUTENANT  Houston Police Department-HPD
#
# ...
